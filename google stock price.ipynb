# %% [markdown]
# # Step 1: Initialization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %% [markdown]
# # Step 2: Data Preprocessing

# %%
# Load the data
dataset = pd.read_csv('/content/Ftrain.csv')

# %%
dataset.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2015-01-02  26.378078  26.490770  26.133251  26.168653  26.168653  28951268
# 1  2015-01-05  26.091366  26.144720  25.582764  25.623152  25.623152  41196796
# 2  2015-01-06  25.679497  25.738087  24.983908  25.029282  25.029282  57998800
# 3  2015-01-07  25.280592  25.292759  24.914099  24.986401  24.986401  41301082
# 4  2015-01-08  24.831326  25.105074  24.482782  25.065184  25.065184  67071641

# %%
dataset.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1505  2020-12-23  86.405502  87.399498  86.251999  86.619003  86.619003
# 1506  2020-12-24  86.750000  87.300003  86.455498  86.942497  86.942497
# 1507  2020-12-28  87.581749  89.536400  87.316750  88.804497  88.804497
# 1508  2020-12-29  89.389503  89.622002  87.804497  87.935997  87.935997
# 1509  2020-12-30  88.100502  88.254753  86.279999  86.975998  86.975998
#
#         Volume
# 1505  20676000
# 1506   6936000
# 1507  27860000
# 1508  25988000
# 1509  26122000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1510 entries, 0 to 1509
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1510 non-null   object
#  1   Open       1510 non-null   float64
#  2   High       1510 non-null   float64
#  3   Low        1510 non-null   float64
#  4   Close      1510 non-null   float64
#  5   Adj Close  1510 non-null   float64
#  6   Volume     1510 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 82.7+ KB

# %%
training_set = dataset.iloc[:, 1:2].values

# %%
training_set
# Out:
# array([[26.378078],
#        [26.091366],
#        [25.679497],
#        ...,
#        [87.581749],
#        [89.389503],
#        [88.100502]])

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Create a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, len(training_set)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshape the data for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# # Step 3: Building LSTM

# %%
# Build the LSTM model
regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# # Step 4: Training the model

# %%
# Train the LSTM model
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 46/46 [==============================] - 19s 158ms/step - loss: 0.0198
# Epoch 2/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0044
# Epoch 3/100
# 46/46 [==============================] - 7s 157ms/step - loss: 0.0038
# Epoch 4/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0051
# Epoch 5/100
# 46/46 [==============================] - 7s 157ms/step - loss: 0.0045
# Epoch 6/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0035
# Epoch 7/100
# 46/46 [==============================] - 7s 156ms/step - loss: 0.0034
# Epoch 8/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0032
# Epoch 9/100
# 46/46 [==============================] - 7s 155ms/step - loss: 0.0035
# Epoch 10/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0034
# Epoch 11/100
# 46/46 [==============================] - 7s 153ms/step - loss: 0.0030
# Epoch 12/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0029
# Epoch 13/100
# 46/46 [==============================] - 7s 154ms/step - loss: 0.0028
# Epoch 14/100
# 46/46 [==============================] - 6s 139ms/step - loss: 0.0028
# Epoch 15/100
# 46/46 [==============================] - 7s 155ms/step - loss: 0.0029
# Epoch 16/100
# 46/46 [==============================] - 7s 151ms/step - loss: 0.0026
# Epoch 17/100
# 46/46 [==============================] - 7s 154ms/step - loss: 0.0025
# Epoch 18/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0029
# Epoch 19/100
# 46/46 [==============================] - 7s 154ms/step - loss: 0.0025
# Epoch 20/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0025
# Epoch 21/100
# 46/46 [==============================] - 7s 157ms/step - loss: 0.0024
# Epoch 22/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0020
# Epoch 23/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0021
# Epoch 24/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0020
# Epoch 25/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0022
# Epoch 26/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0021
# Epoch 27/100
# 46/46 [==============================] - 6s 138ms/step - loss: 0.0019
# Epoch 28/100
# 46/46 [==============================] - 6s 133ms/step - loss: 0.0020
# Epoch 29/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0018
# Epoch 30/100
# 46/46 [==============================] - 6s 135ms/step - loss: 0.0018
# Epoch 31/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0017
# Epoch 32/100
# 46/46 [==============================] - 6s 141ms/step - loss: 0.0017
# Epoch 33/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0017
# Epoch 34/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0016
# Epoch 35/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0015
# Epoch 36/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0016
# Epoch 37/100
# 46/46 [==============================] - 6s 124ms/step - loss: 0.0016
# Epoch 38/100
# 46/46 [==============================] - 7s 143ms/step - loss: 0.0017
# Epoch 39/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0015
# Epoch 40/100
# 46/46 [==============================] - 7s 149ms/step - loss: 0.0013
# Epoch 41/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0017
# Epoch 42/100
# 46/46 [==============================] - 7s 145ms/step - loss: 0.0017
# Epoch 43/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0015
# Epoch 44/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0014
# Epoch 45/100
# 46/46 [==============================] - 6s 124ms/step - loss: 0.0016
# Epoch 46/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0013
# Epoch 47/100
# 46/46 [==============================] - 6s 123ms/step - loss: 0.0014
# Epoch 48/100
# 46/46 [==============================] - 6s 141ms/step - loss: 0.0014
# Epoch 49/100
# 46/46 [==============================] - 6s 124ms/step - loss: 0.0013
# Epoch 50/100
# 46/46 [==============================] - 7s 144ms/step - loss: 0.0016
# Epoch 51/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0014
# Epoch 52/100
# 46/46 [==============================] - 7s 144ms/step - loss: 0.0013
# Epoch 53/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0013
# Epoch 54/100
# 46/46 [==============================] - 7s 140ms/step - loss: 0.0014
# Epoch 55/100
# 46/46 [==============================] - 6s 140ms/step - loss: 0.0012
# Epoch 56/100
# 46/46 [==============================] - 6s 134ms/step - loss: 0.0014
# Epoch 57/100
# 46/46 [==============================] - 7s 145ms/step - loss: 0.0012
# Epoch 58/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0013
# Epoch 59/100
# 46/46 [==============================] - 7s 146ms/step - loss: 0.0012
# Epoch 60/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0012
# Epoch 61/100
# 46/46 [==============================] - 7s 147ms/step - loss: 0.0012
# Epoch 62/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0012
# Epoch 63/100
# 46/46 [==============================] - 7s 146ms/step - loss: 0.0011
# Epoch 64/100
# 46/46 [==============================] - 6s 130ms/step - loss: 9.9824e-04
# Epoch 65/100
# 46/46 [==============================] - 7s 148ms/step - loss: 0.0012
# Epoch 66/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0010
# Epoch 67/100
# 46/46 [==============================] - 7s 149ms/step - loss: 0.0011
# Epoch 68/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0012
# Epoch 69/100
# 46/46 [==============================] - 7s 148ms/step - loss: 0.0011
# Epoch 70/100
# 46/46 [==============================] - 6s 139ms/step - loss: 0.0011
# Epoch 71/100
# 46/46 [==============================] - 6s 136ms/step - loss: 0.0010
# Epoch 72/100
# 46/46 [==============================] - 7s 148ms/step - loss: 0.0010
# Epoch 73/100
# 46/46 [==============================] - 6s 130ms/step - loss: 9.6051e-04
# Epoch 74/100
# 46/46 [==============================] - 7s 148ms/step - loss: 0.0012
# Epoch 75/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0010
# Epoch 76/100
# 46/46 [==============================] - 7s 145ms/step - loss: 9.7157e-04
# Epoch 77/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0010
# Epoch 78/100
# 46/46 [==============================] - 7s 147ms/step - loss: 9.9284e-04
# Epoch 79/100
# 46/46 [==============================] - 6s 129ms/step - loss: 9.3801e-04
# Epoch 80/100
# 46/46 [==============================] - 7s 146ms/step - loss: 0.0011
# Epoch 81/100
# 46/46 [==============================] - 6s 129ms/step - loss: 9.8487e-04
# Epoch 82/100
# 46/46 [==============================] - 7s 147ms/step - loss: 0.0010
# Epoch 83/100
# 46/46 [==============================] - 6s 127ms/step - loss: 9.0557e-04
# Epoch 84/100
# 46/46 [==============================] - 7s 144ms/step - loss: 9.4757e-04
# Epoch 85/100
# 46/46 [==============================] - 6s 132ms/step - loss: 9.4243e-04
# Epoch 86/100
# 46/46 [==============================] - 6s 139ms/step - loss: 0.0010
# Epoch 87/100
# 46/46 [==============================] - 7s 143ms/step - loss: 8.7456e-04
# Epoch 88/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0010
# Epoch 89/100
# 46/46 [==============================] - 7s 145ms/step - loss: 0.0010
# Epoch 90/100
# 46/46 [==============================] - 6s 127ms/step - loss: 8.2472e-04
# Epoch 91/100
# 46/46 [==============================] - 7s 147ms/step - loss: 9.6009e-04
# Epoch 92/100
# 46/46 [==============================] - 6s 132ms/step - loss: 9.8592e-04
# Epoch 93/100
# 46/46 [==============================] - 7s 147ms/step - loss: 0.0011
# Epoch 94/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0011
# Epoch 95/100
# 46/46 [==============================] - 7s 146ms/step - loss: 8.8831e-04
# Epoch 96/100
# 46/46 [==============================] - 6s 128ms/step - loss: 9.3886e-04
# Epoch 97/100
# 46/46 [==============================] - 7s 147ms/step - loss: 9.2987e-04
# Epoch 98/100
# 46/46 [==============================] - 6s 129ms/step - loss: 8.2152e-04
# Epoch 99/100
# 46/46 [==============================] - 7s 146ms/step - loss: 0.0010
# Epoch 100/100
# 46/46 [==============================] - 6s 131ms/step - loss: 8.1546e-04

# %% [markdown]
# # Step 5: Making Predictions

# %%
# Load the test data
test_set = pd.read_csv('/content/Ftest.csv')

# %%
test_set.shape
# Out:
# (38, 7)

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       38 non-null     object
#  1   Open       38 non-null     float64
#  2   High       38 non-null     float64
#  3   Low        38 non-null     float64
#  4   Close      38 non-null     float64
#  5   Adj Close  38 non-null     float64
#  6   Volume     38 non-null     int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
real_stock_price = test_set.iloc[:, 1:2].values

# %%
real_stock_price
# Out:
# array([[ 87.876999],
#        [ 86.25    ],
#        [ 85.1315  ],
#        [ 87.002998],
#        [ 89.399002],
#        [ 89.303497],
#        [ 87.695999],
#        [ 86.929001],
#        [ 87.681   ],
#        [ 86.9095  ],
#        [ 87.612503],
#        [ 91.572998],
#        [ 94.900002],
#        [ 94.783997],
#        [ 96.033501],
#        [ 94.442001],
#        [ 94.126503],
#        [ 92.196999],
#        [ 92.308502],
#        [ 92.678497],
#        [ 96.127998],
#        [103.650002],
#        [103.444504],
#        [103.5     ],
#        [105.295502],
#        [103.927002],
#        [104.710503],
#        [104.975502],
#        [104.512497],
#        [105.218002],
#        [105.      ],
#        [105.519501],
#        [105.963501],
#        [103.349998],
#        [101.250504],
#        [102.091499],
#        [103.372498],
#        [102.526001]])

# %%
real_stock_price.shape
# Out:
# (38, 1)

# %%
# Predict the test data
dataset_total = pd.concat((dataset['Open'], test_set['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
# creating a testset
X_test = []
for i in range(len(training_set) - 60, len(training_set)):
    X_test.append(training_set_scaled[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
#getting predicted stock prices
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 2/2 [==============================] - 2s 37ms/step

# %%
# Keep only the predicted prices for the test data
predicted_stock_price = predicted_stock_price[-len(test_set):]

# %% [markdown]
# # Step 6: Visualiztion

# %%
# Visualize the results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # Step 7: RMSE accuracy

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
accuracy = 100 - rmse
print("Test score: %.2f RMSE" % rmse)
print("Accuracy: %.2f" % accuracy)
# Out:
# Test score: 10.98 RMSE
# Accuracy: 89.02
